# %%
import requests
import pandas as pd
import time
from datetime import datetime

# Replace with your actual API key
API_KEY = "AIzaSyDxMmnUTC06sK9lStCk78MJTI7lOeFJ_MU"

# List of YouTube video URLs
video_urls = [
    "https://youtu.be/7ToBt0KWJw8?si=fE264vIp28GGSUk9",
        "https://youtu.be/12ViUYWuZ6Y?si=Ykr3jwCQohqvxb0x",
        "https://youtu.be/ux56nq7f3Rs?si=RIn5VW4ZchIQT9IU",
        "https://youtu.be/TJY-vcYczjc?si=bxTM-MgcmNZGZi_v",
        "https://youtu.be/Msl7BdI2Mys?si=tST2WMxAEmQ5NQJN",
        "https://youtu.be/nuYldIP_qIo?si=ArYGtCN-KJ0n7ecF",
        "https://youtu.be/NVaMi1E8-9s?si=kPVtBEe7nYyFnA4v",
        "https://youtu.be/bkSkjoS0AkY?si=_SkierzHYtrD0A5z",
        "https://youtu.be/De-9d_GIqCY?si=kxZPjJxQSE4kX_Ys",
        "https://youtu.be/OylS_5L0dAg?si=D7ogRAVHoXteRoyo",
        "https://youtu.be/R3vIgmzZx4o?si=YLNkR4aO6xZ_1B95",
        "https://youtu.be/r0EwuTqmhTI?si=cH-mE1Fq-_8YmGzj",
        "https://youtu.be/FQPiDkEUDfw?si=l7UQ6aBxLeiMDa8A",
        "https://youtu.be/FQPiDkEUDfw?si=CnbXcpSOQH0cTHXo",
        "https://youtu.be/Wpt_7rQ5Feo?si=HtwFTFfyoNSjFBed",
        "https://youtu.be/AGI_ZcqvAB0?si=qSNvcq9b9OAsagSH",
        "https://youtu.be/Ik7KqKZoI8A?si=nXlXUz_Nnbbai7N3",
        "https://youtu.be/PxeF-681Yi0?si=7zw5Q_eFgxXzT09O",
        "https://youtu.be/-aA0RLJptiU?si=k02MeXuNTcc7Hcpa",
        "https://youtu.be/-aA0RLJptiU?si=RdA7tlF7SibUxqYx",
        "https://youtu.be/wxE2SribvWk?si=HiHZ3yqVnIa5KeFz",
        "https://youtu.be/q7PU0iWXhhM?si=WizC4Y5KFQWBBBmt",
        "https://youtu.be/De7l7XoSlM0?si=xSX2z997VhtLmGaM",
        "https://youtu.be/tMOr50wt5pM?si=tiYvEgR2X1RS8OfC",
        "https://youtu.be/bkSkjoS0AkY?si=sKHLaLPf1SESjvhd",
        "https://youtu.be/Iv7z_5f7CqQ?si=19V7Vh6Ilh35aO8F",
        "https://youtu.be/yMe6SE9Vef4?si=6H3WrVkkaiTZsmAv",
        "https://youtu.be/SGiHLYwtTUU?si=9I67T723tZwDS-P7",
        "https://youtu.be/8woWFDiFYpQ?si=6JQefDxiMvTRqi78",
        "https://youtu.be/EiHxfypxMwU?si=KWmnSRYY0E7xP4rb",
    "https://youtu.be/ietY8qQ_2_M?si=VMVXfTkkF6KEOl2t",
        "https://youtu.be/VzoLNqRyuBs?si=WL6kU0h2LDzkbIRX",
        "https://youtu.be/zpSg7am1xZI?si=NGXNP0RgV8moUyIS",
        "https://youtube.com/shorts/_6u5NotHGD4?si=X0fH1tbDt3tOrh6K",
        "https://youtu.be/gaLWS85uCzA?si=hCyLGYmgJxKgYKOw",
        "https://youtube.com/shorts/eo4j_3EAAPU?si=vNW4BLQmgahUAZaL",
        "https://youtu.be/oeVHVa1KDM0?si=rJHU-r5D8O7f4m16",
        "https://youtu.be/IgikWpbM1_0?si=xryayNNbt09GMjBj",
        "https://youtu.be/-eNSdFdyw5A?si=KdcWa66eiafFO1sT",
        "https://youtube.com/shorts/9rlte0bI18E?si=fFXXW9EoaDDYZ_RL",
        "https://youtu.be/jpx07kI6FTs?si=gqjn8L7b_c6Yh-Ad",
        "https://youtu.be/a1EDBt4ya44?si=o9OwcaOKCieB-8Vu",
        "https://youtube.com/shorts/fywpx8nihHo?si=pwzZ0cYeNd6_efZN",
        "https://youtu.be/lflY_l0wZFQ?si=tLJQqzTr38p-gogB",
        "https://youtu.be/sV1Z2LXtHqc?si=gNNjTHWbSzlKDG3O",
        "https://youtu.be/kFpqL9placI?si=nrdP4SPkzlBycOaI",
        "https://youtu.be/7PxxVJ40ZXM?si=Rl5sxMQq2jmSH5eW",
        "https://youtu.be/4ORpgihjExs?si=fceWDYX9a9UYpJvM",
        "https://youtu.be/Zc2TNy6411w?si=8vtCGP-jKU8SHd7Z",
        "https://youtu.be/qcJXEI8-FFo?si=4TUanlDcXs22eUj3",
        "https://youtu.be/c52XZfPK5YE?si=upodXmkN9zZ84HpY",
        "https://youtu.be/N_xl9Z75W80?si=wKrdOiAInahFvecP",
        "https://youtu.be/0tyHQkz2rwg?si=RRynyTNF0n2qIvTP",
        "https://youtu.be/OAoRsMSXfiQ?si=CkPqadOs2HqPcIM8",
        "https://youtu.be/Wq-JwHf4NWA?si=90MUShsIB-EYZ4vH",
        "https://youtu.be/Zz3okD69zOQ?si=8Gp756zRmYzHkx8P",
        "https://youtu.be/J6_KB4B6Ox8?si=Rb6NXyMVdKZypiqw",
        "https://youtu.be/_6mw1tM5MoQ?si=8NL0uQTJLr1VRED9",
        "https://youtu.be/QAW4z3WMf7E?si=uTxFAzdaWj6RFZNO"


]


# Extract video IDs from URLs
video_ids = []
for url in video_urls:
    if "youtu.be/" in url:
        video_ids.append(url.split("youtu.be/")[1].split("?")[0])
    elif "youtube.com/shorts/" in url:  # Handle shorts URLs
        video_ids.append(url.split("youtube.com/shorts/")[1].split("?")[0])
    # add any other url formats here to extract the video ids

def get_video_comments_with_time(video_id):
    """
    Fetches main comments from a YouTube video along with their timestamps.
    """
    url = "https://www.googleapis.com/youtube/v3/commentThreads"
    comments = []
    next_page_token = None

    while True:
        params = {
            "part": "snippet",
            "videoId": video_id,
            "key": API_KEY,
            "maxResults": 100,  # Fetch 100 comments per request (max limit)
            "textFormat": "plainText",
            "pageToken": next_page_token
        }

        response = requests.get(url, params=params)
        if response.status_code == 200:
            data = response.json()
            for item in data.get("items", []):
                comment_snippet = item["snippet"]["topLevelComment"]["snippet"]
                comment_text = comment_snippet["textDisplay"]
                published_at = comment_snippet["publishedAt"]
                published_time = datetime.fromisoformat(published_at.replace('Z', '+00:00'))
                comments.append((video_id, comment_text, published_time))

            # Check if more comments are available
            next_page_token = data.get("nextPageToken")
            if not next_page_token:
                break  # Stop if no more comments
        else:
            print(f"Error {response.status_code}: {response.json()}")
            break

        time.sleep(1)  # Sleep to avoid hitting API rate limits

    return comments

# Collect all comments from all videos
all_comments = []

for video_id in video_ids:
    print(f"Fetching main comments for Video ID: {video_id}...")
    comments = get_video_comments_with_time(video_id)
    all_comments.extend(comments)

# Save data to an Excel sheet
df = pd.DataFrame(all_comments, columns=["Video ID", "Comment", "Published Time"])
# Convert 'Published Time' to timezone-naive datetime objects
df['Published Time'] = df['Published Time'].dt.tz_localize(None)
df.to_excel("youtube_main_comments_with_time1.xlsx", index=False)

print("✅ Main comments with timestamps have been saved to 'youtube_main_comments_with_time.xlsx'.")
# Out:
# Fetching main comments for Video ID: 7ToBt0KWJw8...
# Fetching main comments for Video ID: 12ViUYWuZ6Y...
# Fetching main comments for Video ID: ux56nq7f3Rs...
# Fetching main comments for Video ID: TJY-vcYczjc...
# Fetching main comments for Video ID: Msl7BdI2Mys...
# Fetching main comments for Video ID: nuYldIP_qIo...
# Fetching main comments for Video ID: NVaMi1E8-9s...
# Fetching main comments for Video ID: bkSkjoS0AkY...
# Fetching main comments for Video ID: De-9d_GIqCY...
# Fetching main comments for Video ID: OylS_5L0dAg...
# Fetching main comments for Video ID: R3vIgmzZx4o...
# Fetching main comments for Video ID: r0EwuTqmhTI...
# Fetching main comments for Video ID: FQPiDkEUDfw...
# Fetching main comments for Video ID: FQPiDkEUDfw...
# Fetching main comments for Video ID: Wpt_7rQ5Feo...
# Fetching main comments for Video ID: AGI_ZcqvAB0...
# Fetching main comments for Video ID: Ik7KqKZoI8A...
# Fetching main comments for Video ID: PxeF-681Yi0...
# Fetching main comments for Video ID: -aA0RLJptiU...
# Fetching main comments for Video ID: -aA0RLJptiU...
# Fetching main comments for Video ID: wxE2SribvWk...
# Fetching main comments for Video ID: q7PU0iWXhhM...
# Fetching main comments for Video ID: De7l7XoSlM0...
# Fetching main comments for Video ID: tMOr50wt5pM...
# Fetching main comments for Video ID: bkSkjoS0AkY...
# Fetching main comments for Video ID: Iv7z_5f7CqQ...
# Fetching main comments for Video ID: yMe6SE9Vef4...
# Fetching main comments for Video ID: SGiHLYwtTUU...
# Fetching main comments for Video ID: 8woWFDiFYpQ...
# Fetching main comments for Video ID: EiHxfypxMwU...
# Fetching main comments for Video ID: ietY8qQ_2_M...
# Fetching main comments for Video ID: VzoLNqRyuBs...
# Fetching main comments for Video ID: zpSg7am1xZI...
# Fetching main comments for Video ID: 3v8mUoQBbSs...
# Fetching main comments for Video ID: qLO5PSoonjQ...
# Fetching main comments for Video ID: bQIe_cWTfrM...
# Fetching main comments for Video ID: NtVqZd2oIxo...
# Fetching main comments for Video ID: S7d07mFjXaY...
# Fetching main comments for Video ID: J5SdnBPBvRM...
# Fetching main comments for Video ID: H-lxIBR-u-Q...
# Fetching main comments for Video ID: Oxptm7fx9XA...
# Fetching main comments for Video ID: 4XR-UGvU1yM...
# Fetching main comments for Video ID: N_xl9Z75W80...
# Fetching main comments for Video ID: cFtfR4pxkbM...
# Fetching main comments for Video ID: 0fLVc5_2oLs...
# Fetching main comments for Video ID: Z-AFPgX1n9c...
# Fetching main comments for Video ID: 0jFrNow4FIM...
# Fetching main comments for Video ID: a4ra88NcmUY...
# Fetching main comments for Video ID: S7d07mFjXaY...
# Fetching main comments for Video ID: Wpt_7rQ5Feo...
# Fetching main comments for Video ID: ietY8qQ_2_M...
# Fetching main comments for Video ID: -aA0RLJptiU...
# Fetching main comments for Video ID: NVaMi1E8-9s...
# Fetching main comments for Video ID: wxE2SribvWk...
# Fetching main comments for Video ID: VzoLNqRyuBs...
# Fetching main comments for Video ID: PxeF-681Yi0...
# Fetching main comments for Video ID: bQIe_cWTfrM...
# Fetching main comments for Video ID: wVktdXS_mkY...
# Fetching main comments for Video ID: Ik7KqKZoI8A...
# Fetching main comments for Video ID: O-9vhxhs1YE...
# Fetching main comments for Video ID: 7ToBt0KWJw8...
# Fetching main comments for Video ID: JiwEYrlD92M...
# Fetching main comments for Video ID: 7PxxVJ40ZXM...
# Fetching main comments for Video ID: Pp2flRi-ZHQ...
# Fetching main comments for Video ID: fOTGMsFAVpI...
# Fetching main comments for Video ID: YmAAz3s8A8c...
# Fetching main comments for Video ID: EY5seEH0fTo...
# Fetching main comments for Video ID: 6wL9wA09W_4...
# Fetching main comments for Video ID: f_W5LOk9UDY...
# Fetching main comments for Video ID: OylS_5L0dAg...
# Fetching main comments for Video ID: UGdL4eIwc8o...
# Fetching main comments for Video ID: pTOmiZOW-ys...
# Fetching main comments for Video ID: HBsKOYuai3U...
# Fetching main comments for Video ID: wKgx-_9mP4U...
# Fetching main comments for Video ID: _6mw1tM5MoQ...
# Fetching main comments for Video ID: AbGouj-_p_s...
# Fetching main comments for Video ID: gMb4PmQab-c...
# Fetching main comments for Video ID: fU0e98oSluk...
# Fetching main comments for Video ID: 8R1sUrhTiGU...
# Fetching main comments for Video ID: lQwoix0KRvo...
# Fetching main comments for Video ID: 18GtEQRUfdg...
# Fetching main comments for Video ID: UqFPmhSNioE...
# Fetching main comments for Video ID: Xo0bKpWzwNg...
# Fetching main comments for Video ID: ehWrrR9aKsg...
# Fetching main comments for Video ID: B6afu7Tpl30...
# Fetching main comments for Video ID: 4O4tALBRRTY...
# Fetching main comments for Video ID: O-zqSfpc3R8...
# Fetching main comments for Video ID: C-unk9O32T0...
# Fetching main comments for Video ID: 3dFfYUnztcM...
# Fetching main comments for Video ID: Ihv04VaoKI8...
# Fetching main comments for Video ID: Z-AFPgX1n9c...
# Fetching main comments for Video ID: KNeyLMw1XUY...
# Fetching main comments for Video ID: wKgx-_9mP4U...
# Fetching main comments for Video ID: twAPhBna7_I...
# Fetching main comments for Video ID: dlF95WCuoXY...
# Fetching main comments for Video ID: 0bFs7ZYUxGQ...
# Fetching main comments for Video ID: VyAn4wgUchs...
# Fetching main comments for Video ID: 5nbI3p-28SM...
# Fetching main comments for Video ID: bXmccB9Ga74...
# Fetching main comments for Video ID: xR98d5JPJbY...
# Fetching main comments for Video ID: Iv7z_5f7CqQ...
# Fetching main comments for Video ID: mAzJquRtN7k...
# Fetching main comments for Video ID: 5YicpQphqWw...
# Fetching main comments for Video ID: l2fef7sAKXE...
# Fetching main comments for Video ID: WZ_ypoWYduw...
# Fetching main comments for Video ID: _6u5NotHGD4...
# Fetching main comments for Video ID: gaLWS85uCzA...
# Fetching main comments for Video ID: eo4j_3EAAPU...
# Fetching main comments for Video ID: oeVHVa1KDM0...
# Fetching main comments for Video ID: IgikWpbM1_0...
# Fetching main comments for Video ID: -eNSdFdyw5A...
# Fetching main comments for Video ID: 9rlte0bI18E...
# Fetching main comments for Video ID: jpx07kI6FTs...
# Fetching main comments for Video ID: a1EDBt4ya44...
# Fetching main comments for Video ID: fywpx8nihHo...
# Fetching main comments for Video ID: lflY_l0wZFQ...
# Fetching main comments for Video ID: sV1Z2LXtHqc...
# Fetching main comments for Video ID: kFpqL9placI...
# Fetching main comments for Video ID: 7PxxVJ40ZXM...
# Fetching main comments for Video ID: 4ORpgihjExs...
# Fetching main comments for Video ID: Zc2TNy6411w...
# Fetching main comments for Video ID: qcJXEI8-FFo...
# Fetching main comments for Video ID: c52XZfPK5YE...
# Fetching main comments for Video ID: N_xl9Z75W80...
# Fetching main comments for Video ID: 0tyHQkz2rwg...
# Fetching main comments for Video ID: OAoRsMSXfiQ...
# Fetching main comments for Video ID: Wq-JwHf4NWA...
# Fetching main comments for Video ID: Zz3okD69zOQ...
# Fetching main comments for Video ID: J6_KB4B6Ox8...
# Fetching main comments for Video ID: _6mw1tM5MoQ...
# Fetching main comments for Video ID: QAW4z3WMf7E...
# ✅ Main comments with timestamps have been saved to 'youtube_main_comments_with_time.xlsx'.

# %%
print(df.head())
# Out:
#       Video ID                                            Comment  \
# 0  7ToBt0KWJw8  The best way to deal with scammers is to avoid...
# 1  7ToBt0KWJw8                      You talk too much.gets boring
# 2  7ToBt0KWJw8  Well said, so funny and scary with that scamme...
# 3  7ToBt0KWJw8                        මොහු නිතිය හමුවට පමුණවා ඇත.
# 4  7ToBt0KWJw8  Luckily we have camaras to avoid this hypocrit...
#
#        Published Time
# 0 2025-03-24 20:16:29
# 1 2025-03-10 12:34:41
# 2 2025-03-09 20:54:10
# 3 2025-03-09 13:45:13
# 4 2025-03-04 20:43:06
